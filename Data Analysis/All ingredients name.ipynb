# %%
import numpy as np
import pandas as pd

# %%
with np.load('/content/drive/MyDrive/Food/simplified-recipes-1M.npz', allow_pickle=True) as data:
    recipes = data['recipes']
    ingredients = data['ingredients']

# %%
ingredients
# Out:
# array(['salt', 'pepper', 'butter', ..., 'watercress leaves',
#        'emerils essence', 'corn flakes cereal'], dtype='<U39')

# %%
com_df = pd.DataFrame({'In':ingredients})

# %%
com_df.to_csv('comp_ingredients6.csv')
